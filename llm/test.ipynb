# %%
import torch

torch.cuda
# Out:
# <module 'torch.cuda' from 'd:\\Workspace\\capstone-project\\llm\\.venv\\Lib\\site-packages\\torch\\cuda\\__init__.py'>

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 3050 Laptop GPU'

# %%
torch.cuda.mem_get_info()
# Out:
# (3463865959, 4294443008)
